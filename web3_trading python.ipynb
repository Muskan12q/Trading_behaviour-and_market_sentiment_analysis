# %%
import pandas as pd

# %%
import numpy as np

# %%
trades = pd.read_csv(r"C:\Users\musus\Downloads\historical_data.csv")

# %%
sentiment = pd.read_csv(r"C:\Users\musus\Downloads\fear_greed_index.csv")

# %%
trades.head(10)
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
# 5  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9900
# 6  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9934
# 7  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           8.0000
# 8  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           8.0000
# 9  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           8.0000
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# ...

# %%
sentiment.head(10)
# Out:
#     timestamp  value classification        date
# 0  1517463000     30           Fear  2018-02-01
# 1  1517549400     15   Extreme Fear  2018-02-02
# 2  1517635800     40           Fear  2018-02-03
# 3  1517722200     24   Extreme Fear  2018-02-04
# 4  1517808600     11   Extreme Fear  2018-02-05
# 5  1517895000      8   Extreme Fear  2018-02-06
# 6  1517981400     36           Fear  2018-02-07
# 7  1518067800     30           Fear  2018-02-08
# 8  1518154200     44           Fear  2018-02-09
# 9  1518240600     54        Neutral  2018-02-10

# %%
trades['date'] = pd.to_datetime(trades['Timestamp IST'], dayfirst = True).dt.date

# %%
trades.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %%
sentiment['date'] = pd.to_datetime(sentiment['date']).dt.date

# %%
sentiment.head()
# Out:
#     timestamp  value classification        date
# 0  1517463000     30           Fear  2018-02-01
# 1  1517549400     15   Extreme Fear  2018-02-02
# 2  1517635800     40           Fear  2018-02-03
# 3  1517722200     24   Extreme Fear  2018-02-04
# 4  1517808600     11   Extreme Fear  2018-02-05

# %%
merged_da = pd.merge( trades, sentiment, on = 'date', how = 'left')

# %%
merged_da.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %%
merged_da.isnull().sum()
# Out:
# Account             0
# Coin                0
# Execution Price     0
# Size Tokens         0
# Size USD            0
# Side                0
# Timestamp IST       0
# Start Position      0
# Direction           0
# Closed PnL          0
# Transaction Hash    0
# Order ID            0
# Crossed             0
# Fee                 0
# Trade ID            0
# Timestamp           0
# date                0
# timestamp           6
# value               6
# classification      6
# dtype: int64

# %%
merged_da.describe()
# Out:
#        Execution Price   Size Tokens      Size USD  Start Position  \
# count    211224.000000  2.112240e+05  2.112240e+05    2.112240e+05
# mean      11414.723350  4.623365e+03  5.639451e+03   -2.994625e+04
# std       29447.654868  1.042729e+05  3.657514e+04    6.738074e+05
# min           0.000005  8.740000e-07  0.000000e+00   -1.433463e+07
# 25%           4.854700  2.940000e+00  1.937900e+02   -3.762311e+02
# 50%          18.280000  3.200000e+01  5.970450e+02    8.472793e+01
# 75%         101.580000  1.879025e+02  2.058960e+03    9.337278e+03
# max      109004.000000  1.582244e+07  3.921431e+06    3.050948e+07
#
#           Closed PnL      Order ID            Fee      Trade ID     Timestamp  \
# count  211224.000000  2.112240e+05  211224.000000  2.112240e+05  2.112240e+05
# mean       48.749001  6.965388e+10       1.163967  5.628549e+14  1.737744e+12
# std       919.164828  1.835753e+10       6.758854  3.257565e+14  8.689920e+09
# ...

# %%
#merged_da = merged_da.drop(columns = ['Date'])

# %%
merged_da.columns = merged_da.columns.str.lower()

# %%
merged_da.columns = merged_da.columns.str.replace(' ','_')

# %%
merged_da.columns
# Out:
# Index(['account', 'coin', 'execution_price', 'size_tokens', 'size_usd', 'side',
#        'timestamp_ist', 'start_position', 'direction', 'closed_pnl',
#        'transaction_hash', 'order_id', 'crossed', 'fee', 'trade_id',
#        'timestamp', 'date', 'timestamp', 'value', 'classification'],
#       dtype='object')

# %%
merged_da['classification'] = merged_da['classification'].fillna('unknown')

# %%
merged_da.isnull().sum()
# Out:
# account             0
# coin                0
# execution_price     0
# size_tokens         0
# size_usd            0
# side                0
# timestamp_ist       0
# start_position      0
# direction           0
# closed_pnl          0
# transaction_hash    0
# order_id            0
# crossed             0
# fee                 0
# trade_id            0
# timestamp           0
# date                0
# timestamp           6
# value               6
# classification      0
# dtype: int64

# %%
merged_da.head(10)
# Out:
#                                       account  coin  execution_price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
# 5  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9900
# 6  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9934
# 7  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           8.0000
# 8  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           8.0000
# 9  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           8.0000
#
#    size_tokens  size_usd side     timestamp_ist  start_position direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# ...

# %%
merged_da = merged_da.drop(columns = ['timestamp'])

# %%
merged_da.head(10)
# Out:
#                                       account  coin  execution_price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
# 5  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9900
# 6  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9934
# 7  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           8.0000
# 8  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           8.0000
# 9  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           8.0000
#
#    size_tokens  size_usd side     timestamp_ist  start_position direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# ...

# %%
merged_da = merged_da.dropna()

# %%
merged_da.isnull().sum()
# Out:
# account             0
# coin                0
# execution_price     0
# size_tokens         0
# size_usd            0
# side                0
# timestamp_ist       0
# start_position      0
# direction           0
# closed_pnl          0
# transaction_hash    0
# order_id            0
# crossed             0
# fee                 0
# trade_id            0
# date                0
# value               0
# classification      0
# dtype: int64

# %%
(merged_da['side']== merged_da['direction']).all()
# Out:
# np.False_

# %%
merged_da.dtypes
# Out:
# account              object
# coin                 object
# execution_price     float64
# size_tokens         float64
# size_usd            float64
# side                 object
# timestamp_ist        object
# start_position      float64
# direction            object
# closed_pnl          float64
# transaction_hash     object
# order_id              int64
# crossed                bool
# fee                 float64
# trade_id            float64
# date                 object
# value               float64
# classification       object
# dtype: object

# %%
merged_da['timestamp_ist'] = pd.to_datetime(merged_da['timestamp_ist'],format="%d-%m-%Y %H:%M")

# %%
merged_da.dtypes
# Out:
# account                     object
# coin                        object
# execution_price            float64
# size_tokens                float64
# size_usd                   float64
# side                        object
# timestamp_ist       datetime64[ns]
# start_position             float64
# direction                   object
# closed_pnl                 float64
# transaction_hash            object
# order_id                     int64
# crossed                       bool
# fee                        float64
# trade_id                   float64
# date                        object
# value                      float64
# classification              object
# dtype: object

# %%
merged_da['date'] = pd.to_datetime(merged_da['date']).dt.date

# %%
merged_da['trade_id'] = merged_da['trade_id'].astype(int)

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
username = "postgres"
password = "11oct2023"
host = "localhost"
port = "5432"
database = "web3_trading"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

table_name = "trading"
merged_da.to_sql(table_name, engine, if_exists = "replace", index = False)

print(f" data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
#  data successfully loaded into table 'trading' in database 'web3_trading'.

# %%
import matplotlib.pyplot as plt

# %%
trade_count = merged_da.groupby('classification').size().reset_index(name='trade_count')
trade_count
# Out:
#   classification  trade_count
# 0   Extreme Fear        21400
# 1  Extreme Greed        39992
# 2           Fear        61837
# 3          Greed        50303
# 4        Neutral        37686

# %%
plt.figure()
plt.bar(trade_count['classification'], trade_count['trade_count'], width = 0.4)
plt.xlabel('Market Sentiment')
plt.ylabel('Number of Trades')
plt.title('Trade Frequency vs Market Sentiment')
plt.show()
